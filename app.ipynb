# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./Datasets/flats.csv")

# %%
df
# Out:
#                          property_name  \
# 0         2 BHK Flat in Krishna Colony
# 1            2 BHK Flat in Ashok Vihar
# 2                  2 BHK Flat in Sohna
# 3      2 BHK Flat in Sector 61 Gurgaon
# 4      2 BHK Flat in Sector 92 Gurgaon
# ...                                ...
# 3023   3 BHK Flat in Sector 86 Gurgaon
# 3024   5 BHK Flat in Sector 48 Gurgaon
# 3025  3 BHK Flat in Sector 108 Gurgaon
# 3026         3 BHK Flat in DLF Phase 3
# 3027   4 BHK Flat in Sector 54 Gurgaon
#
#                                                    link  \
# 0     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 1     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 2     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 3     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 4     https://www.99acres.com/2-bhk-bedroom-apartmen...
# ...                                                 ...
# 3023  https://www.99acres.com/3-bhk-bedroom-apartmen...
# ...

# %%
df.info()

# %%
df.property_id.value_counts()
# Out:
# property_id
# I69037888    2
# U68944572    2
# B58881018    2
# M69068068    2
# L69620694    2
#             ..
# P63014096    1
# U66115782    1
# X66115252    1
# Y43156359    1
# V70296402    1
# Name: count, Length: 2875, dtype: int64

# %%
df[df.property_id=="U68944572"] == df[df.property_id=="U68944572"]
# Out:
#       property_name  link  society  price  area  areaWithType  bedRoom  \
# 2577           True  True     True   True  True          True     True
# 2687           True  True     True   True  True          True     True
#
#       bathroom  balcony  additionalRoom  address  floorNum  facing  \
# 2577      True     True            True     True      True    True
# 2687      True     True            True     True      True    True
#
#       agePossession  nearbyLocations  description  furnishDetails  features  \
# 2577           True             True         True            True      True
# 2687           True             True         True            True      True
#
#       rating  property_id
# 2577    True         True
# 2687    True         True

# %%
df.equals
# Out:
#                          property_name  \
# 0         2 BHK Flat in Krishna Colony
# 1            2 BHK Flat in Ashok Vihar
# 2                  2 BHK Flat in Sohna
# 3      2 BHK Flat in Sector 61 Gurgaon
# 4      2 BHK Flat in Sector 92 Gurgaon
# ...                                ...
# 3023   3 BHK Flat in Sector 86 Gurgaon
# 3024   5 BHK Flat in Sector 48 Gurgaon
# 3025  3 BHK Flat in Sector 108 Gurgaon
# 3026         3 BHK Flat in DLF Phase 3
# 3027   4 BHK Flat in Sector 54 Gurgaon
#
#                                                    link  \
# 0     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 1     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 2     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 3     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 4     https://www.99acres.com/2-bhk-bedroom-apartmen...
# ...                                                 ...
# 3023  https://www.99acres.com/3-bhk-bedroom-apartmen...
# ...

# %%
x=df.drop_duplicates(subset="property_id")

# %%
# Out:
#                          property_name  \
# 0         2 BHK Flat in Krishna Colony
# 1            2 BHK Flat in Ashok Vihar
# 2                  2 BHK Flat in Sohna
# 3      2 BHK Flat in Sector 61 Gurgaon
# 4      2 BHK Flat in Sector 92 Gurgaon
# ...                                ...
# 3023   3 BHK Flat in Sector 86 Gurgaon
# 3024   5 BHK Flat in Sector 48 Gurgaon
# 3025  3 BHK Flat in Sector 108 Gurgaon
# 3026         3 BHK Flat in DLF Phase 3
# 3027   4 BHK Flat in Sector 54 Gurgaon
#
#                                                    link  \
# 0     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 1     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 2     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 3     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 4     https://www.99acres.com/2-bhk-bedroom-apartmen...
# ...                                                 ...
# 3023  https://www.99acres.com/3-bhk-bedroom-apartmen...
# ...

# %%
# Out:
# True
